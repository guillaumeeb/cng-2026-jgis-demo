# %% [markdown]
# **NOTE: This Notebook requires the "play" dependency group to be installed (`uv sync --all-groups`)**
#
# This notebook was originally posted [here](https://github.com/guillaumeeb/supaero-otsu-course/blob/27de0375d3aa60a4c6278b123aa5c80fc6c3d650/.github/ndsi_sol.ipynb).

# %% [markdown]
# # OTSU Big Data Cloud BE
#
# Welcome to this training of ISAE Supaero OTSU Cloud, Big Data and Machine Learning module.
#
# The end goal of this exercise is to build temporal statistics from several Seninel-2 L2A products accessed from an object storage. In order to do this, we'll read the products using (rio)Xarray with a Dask backend, directly from Google Cloud Storage, compute a NDSI over ten dates and plot snow cover evolution accross the period.
#
# By doing this, we will learn the folowing things:
#
# - How to access a Cloud storage and browse its objects,
# - How to use rioxarray to access and load Satellite imagery,
# - How to use Xarray Dataset class to build a complete timeseries dataset,
# - How to chunk our data and use Dask to perform bigger than memory or distributed analysis over our entire dataset.

# %% [markdown]
# ## Imports and settings
#
# As always, this begins with imports. We set some environment variable to easily acces Google Cloud Storage anonymously.

# %%
import os

import gcsfs
import leafmap
import pandas as pd
import rioxarray
import xarray as xr
from distributed import Client

# %%
def set_env() -> None:
    os.environ["GS_NO_SIGN_REQUEST"] = "YES"


set_env()

# %%
NODATA = -10000

# %% [markdown]
# ## Check you have access to GCS bucket
#
# We can use gcsfs package, which mimics a file system usage on an object storage.
#
# It is pretty easy on a public bucket with anonymous access authorized, like the one we use. You can see that an object store with fsspec can behave a lot like a standard fil system. Just don't forget it is not.

# %%
fs = gcsfs.GCSFileSystem(bucket_name="supaero", token="anon")  # noqa: S106

# %%
fs.ls("supaero/31TCH")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781600715.215029 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.259058 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.295537 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.340379 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.392537 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.441874 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.494960 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.548423 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.598534 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.641346 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.683960 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.719968 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.756442 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.797912 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.834454 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.872399 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.206401 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.246264 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.258534 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.401662 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.415198 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.428838 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.492121 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.564473 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.609367 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.641988 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.703871 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.749914 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.758999 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.763045 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.824428 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.972732 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.676889 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.813395 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.869235 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.891832 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.911750 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.922147 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.024279 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.127411 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.139820 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.271915 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.274696 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.294262 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.302692 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.431745 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.495006 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.610921 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.090044 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.144928 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.322076 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.329189 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.433332 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.611337 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.635953 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.642003 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.782788 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.921267 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.941139 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.024067 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.028311 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.136013 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.237677 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.267769 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600723.676014 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600723.984204 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.008280 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.514852 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.587045 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.633168 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.666432 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.705860 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.928348 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.981542 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.106223 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.111507 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.198853 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.207997 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.528170 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.838987 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fs.ls("supaero/31TCH")
#
# File /work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File /work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/fsspec/asyn.py:91, in sync(loop, func, timeout, *args, **kwargs)
#      88 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      89 while True:
#      90     # this loops allows thread to get interrupted
# ---> 91     if event.wait(1):
#      92         break
#      93     if timeout is not None:
#
# File /work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# Could not determine bucket type for bucket name supaero: Timeout of 60.0s exceeded, last exception: 503 failed to connect to all addresses; last error: UNKNOWN: ipv4:142.251.36.219:443: Ssl handshake failed (TSI_PROTOCOL_FAILURE): SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain (errors resolving storage.googleapis.com: [field:srv lookup error:SRV lookup failed for _grpclb._tcp.storage.googleapis.com: DNS server returned answer with no data]), falling back to GCSFileSystem
# _request out of retries on exception: Cannot connect to host storage.googleapis.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1010)')]
# Traceback (most recent call last):
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/connector.py", line 1316, in _wrap_create_connection
#     return await self._loop.create_connection(*args, **kwargs, sock=sock)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/asyncio/base_events.py", line 1159, in create_connection
#     transport, protocol = await self._create_connection_transport(
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/asyncio/base_events.py", line 1192, in _create_connection_transport
#     await waiter
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/asyncio/sslproto.py", line 581, in _on_handshake_complete
#     raise handshake_exc
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/asyncio/sslproto.py", line 563, in _do_handshake
#     self._sslobj.do_handshake()
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/ssl.py", line 916, in do_handshake
#     self._sslobj.do_handshake()
# ssl.SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1010)
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/gcsfs/retry.py", line 153, in retry_request
#     return await func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/gcsfs/core.py", line 488, in _request
#     async with self.session.request(
#                ^^^^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/client.py", line 1683, in __aenter__
#     self._resp: _RetType_co = await self._coro
#                               ^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/client.py", line 856, in _request
#     resp = await handler(req)
#            ^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/client.py", line 810, in _connect_and_send_request
#     conn = await self._connector.connect(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/connector.py", line 657, in connect
#     proto = await self._create_connection(req, traces, timeout)
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/connector.py", line 1242, in _create_connection
#     _, proto = await self._create_direct_connection(req, traces, timeout)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/connector.py", line 1620, in _create_direct_connection
#     raise last_exc
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/connector.py", line 1589, in _create_direct_connection
#     transp, proto = await self._wrap_create_connection(
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/aiohttp/connector.py", line 1318, in _wrap_create_connection
#     raise ClientConnectorCertificateError(req.connection_key, exc) from exc
# aiohttp.client_exceptions.ClientConnectorCertificateError: Cannot connect to host storage.googleapis.com:443 ssl:True [SSLCertVerificationError: (1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1010)')]
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1781600715.215029 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.259058 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.295537 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.340379 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.392537 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.441874 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.494960 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.548423 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.598534 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.641346 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.683960 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.719968 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.756442 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.797912 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.834454 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600715.872399 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.206401 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.246264 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.258534 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.401662 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.415198 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.428838 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.492121 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.564473 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.609367 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.641988 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.703871 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.749914 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.758999 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.763045 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.824428 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600716.972732 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.676889 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.813395 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.869235 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.891832 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.911750 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600717.922147 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.024279 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.127411 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.139820 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.271915 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.274696 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.294262 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.302692 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.431745 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.495006 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600718.610921 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.090044 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.144928 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.322076 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.329189 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.433332 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.611337 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.635953 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.642003 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.782788 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.921267 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600720.941139 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.024067 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.028311 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.136013 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.237677 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600721.267769 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600723.676014 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600723.984204 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.008280 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.514852 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.587045 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.633168 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.666432 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.705860 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.928348 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600724.981542 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.106223 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.111507 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.198853 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.207997 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.528170 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600725.838987 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 fs.ls("supaero/31TCH")
#
# File /work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/fsspec/asyn.py:118, in sync_wrapper.<locals>.wrapper(*args, **kwargs)
#     115 @functools.wraps(func)
#     116 def wrapper(*args, **kwargs):
#     117     self = obj or args[0]
# --> 118     return sync(self.loop, func, *args, **kwargs)
#
# File /work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/site-packages/fsspec/asyn.py:91, in sync(loop, func, timeout, *args, **kwargs)
#      88 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      89 while True:
#      90     # this loops allows thread to get interrupted
# ---> 91     if event.wait(1):
#      92         break
#      93     if timeout is not None:
#
# File /work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File /work/scratch/env/eynardbg/.conda/envs/jgis-pangeo/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
fs.ls("supaero/31TCH/SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2")
# Out:
# I0000 00:00:1781600729.329096 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600729.432332 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600730.005795 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600730.019744 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600730.019765 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600730.534810 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600730.968986 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600731.094289 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600731.100684 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600731.127211 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600731.282205 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600731.293744 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600731.418943 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600731.649807 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600731.883741 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600732.533704 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600738.777131 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600739.495912 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600739.986123 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600740.878862 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600741.235566 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600741.748605 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600741.764912 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600742.176547 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600742.518692 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600742.798875 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600743.152716 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600743.303261 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600743.367030 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600743.658901 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600743.735124 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600744.334618 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600752.305005 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600758.194275 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600758.662913 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600758.775365 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600759.038127 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600759.147920 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600759.438343 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600759.583733 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600759.706306 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600759.853929 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600760.417071 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600760.687877 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600761.452899 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600761.702968 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600761.886657 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600762.230345 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600780.370627 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600782.493845 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600784.992218 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600785.172908 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600785.778246 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600788.439359 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600789.189072 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600789.407178 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600790.226200 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600790.323658 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600790.338589 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600790.368690 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600790.715614 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600790.749787 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600792.519538 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600793.935620 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600816.948207 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600823.904448 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600826.900935 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600828.939464 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600830.741651 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600833.237106 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600833.414277 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600833.830821 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600834.699556 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600835.576811 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600836.653003 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600837.647326 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600839.416865 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600839.701620 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600840.202023 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600842.623852 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600876.925477 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600886.088355 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600891.556125 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600892.705146 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600893.230966 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600894.627127 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600899.239074 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600900.803076 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600905.169080 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600905.560164 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600910.899094 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600912.697041 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600913.920825 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600915.363024 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600919.652121 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600920.814097 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600979.900461 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600982.947720 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600987.477111 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600992.679460 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781600999.043881 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601001.587662 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601005.297570 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601005.686564 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601009.522634 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601010.208635 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601011.235659 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601012.731349 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601013.015973 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601013.413643 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601015.272190 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601015.308027 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601016.099084 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601016.391937 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601017.566558 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601017.761986 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601019.867953 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601019.899970 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601023.803555 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601024.010702 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601029.130923 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601029.897215 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601031.618787 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601039.738661 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601040.882531 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601056.058638 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601057.063128 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601080.926171 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601083.741355 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601085.381999 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601096.564027 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601098.139236 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601114.936335 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601123.596290 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601124.967365 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601125.767479 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601128.780448 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601131.697851 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601134.416860 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601135.916923 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601138.044498 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601142.467716 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601146.755577 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601146.905473 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601147.243425 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601191.602206 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601200.313470 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601208.113170 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601211.208124 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601228.328902 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601238.321565 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601238.659338 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601246.764512 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601247.533245 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601252.202070 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601254.649471 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601257.774370 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601259.248217 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601259.496668 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601266.672494 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601289.239278 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601304.880633 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601330.234948 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601334.342716 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601338.307561 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601342.980919 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601343.326639 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601353.448718 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601354.471356 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601356.511940 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601364.389806 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601367.008822 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601378.037998 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601378.797743 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601381.473702 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601391.029416 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601411.033715 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601441.559241 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601446.968443 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601452.156325 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601462.481464 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601464.666625 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601470.331664 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601474.880040 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601482.191069 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601486.562851 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601487.532363 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601492.026145 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601504.405148 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601504.753140 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601517.590164 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601518.361415 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601541.600069 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601553.659340 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601554.942408 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601559.421388 1746375 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601564.686904 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601572.033315 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601581.440076 1746375 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601583.627490 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601612.206123 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601614.956634 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601615.440565 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601620.844349 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601620.992836 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601624.411626 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601635.930566 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601650.789775 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601651.912047 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601658.710532 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601662.577316 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601662.725889 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601692.097509 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601693.633744 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601704.763868 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601709.196743 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601724.894387 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601725.954346 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601736.254645 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601736.457771 1746384 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601746.168207 1746375 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601757.505136 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601758.932017 1746375 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601760.037728 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# ...
# I0000 00:00:1781601917.185571 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601917.674846 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601918.176222 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601919.881854 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601921.156010 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601923.269810 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601925.691718 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601926.056509 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601927.255783 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601929.779566 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601931.513666 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601936.402935 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601940.575152 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601942.323312 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601955.734958 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601957.701841 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601960.379205 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601964.163510 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601974.862203 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601985.076509 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601985.707780 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601987.105401 1746381 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781601997.436501 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602013.519134 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602021.415409 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602023.072259 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602023.432751 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602030.384672 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602034.586189 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602039.632009 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602043.784524 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602044.453591 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602045.912716 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602055.133967 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602058.936907 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602072.875916 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602077.190458 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602080.286747 1746376 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602093.357680 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602105.610243 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602116.008578 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602120.333963 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602151.683781 1746375 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602157.424162 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602158.463918 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602162.130622 1746387 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602163.772420 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602167.670199 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602174.605675 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602178.479745 1746388 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602178.712900 1746375 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602185.175160 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602190.068579 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602192.777595 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602196.951762 1746385 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602207.702006 1746386 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602219.926577 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602237.105649 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602273.247625 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602279.651863 1746379 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602281.569462 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602283.172037 1746383 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602292.837478 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602295.081365 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602297.864696 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602298.741252 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602303.785436 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602306.153847 1746377 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602309.671383 1746390 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602311.891551 1746389 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602318.104211 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602320.700736 1746382 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602321.410446 1746380 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain
# I0000 00:00:1781602342.985176 1746378 ssl_transport_security.cc:1756] Handshake failed with error SSL_ERROR_SSL: error:0A000086:SSL routines::certificate verify failed: self-signed certificate in certificate chain

# %% [markdown]
# ### The products
#
# As you can see, we'll use Sentinel-2 L2A products, which have been create using Maja algorithm from CNES.
# Do not hesitate to check Maja or [Theia website](https://www.theia-land.fr/en/blog/product/sentinel-2-surface-reflectance/) to know more about these.
#
# For example :
#
# - How many bands a product has?
# - What correction to the L1C product does MAJA makes?
# - Have every band the same resolution (this is important for the following)?

# %% [markdown]
# ## Reading a product band using rioxarray and rasterio
#
# Rasterio is the Pythonic interface to GDAL, the go to tool when dealing with satelite products. Rioxarray is a library that makes it easy to read rasterio compatible products as Xarray DataArray or Datasets.
#
# At first, we'll read only a subsection of a product, using classical Numpy slices. This way, only selected pixels will be loaded into memory (important when using Dask afterwards, and to not blow up your computer or server memory).
#
# Just use the rioxarray.open_rasterio function to open a random tif file from above, then slice it in order to keep x and y dimension from pixels 4000 to 5000.
# Wee'll have use an URL like "gs://bucket/path".
#
# Opening the file should be pretty fast. Then plot the dataset in another cell, data should really be accessed at this point.

# %%
# %%time
swir = rioxarray.open_rasterio(
    "gs://supaero/31TCH/SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2/SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2_FRE_B11.tif"
)
swir = swir[:, 4000:5000, 4000:5000]
swir

# %%
# %%time
swir.plot()

# %% [markdown]
# Even with the swir band, we can see we are in mountainous area.

# %% [markdown]
# ## Building a single date Dataset
#
# First, without using Dask, will build an Xarray Dataset from two DataArray that share the same dimensions and coordinates.
#
# As we'll read two bands that to not share the same resolution, we'll have to resample the green band (using a simple mean).
#
# Then, we'll use the Dataset to compute two more variable, NDSI, and snow mask.
#
# ### Build DataArrays
#
# So first, we'll read the swir band as from above, but this time, we'll need to make sure that we handle the nodata value correctly (this will be important in the next part of this exercise). To do so, as these L2A products are note really standard, we need to manually remove the no data values using a filter. Then write it in rioxarray metadata.
#
# So open the swir band as above, slice it the same way, but then user xarray.where to remove nodata values (-10_000), and use rioxarray write_no_data with encoded and inplace kwargs to set it correctly inside the data array.

# %%
swir = rioxarray.open_rasterio(
    "gs://supaero/31TCH/SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2/SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2_FRE_B11.tif"
)
swir = swir[:, 4000:5000, 4000:5000]
# No data handling
swir = swir.where(swir != NODATA)
swir.rio.write_nodata(NODATA, encoded=True, inplace=True)
swir

# %%
swir.plot()

# %% [markdown]
# Note that Xarray with numpy backend is already a bit lazy:
# - If you only open a file, only its metadata are read, nothing is loaded until an operation like plot or load is performed.
# - When applying a metadata filter, we transform and load the data, how can you see it in the HTML representation of the DataArray in the notebook?

# %% [markdown]
# Now, we need to open the green band. Note that its resolution is two times better on spatial dimension than the SWIR band.
#
# In order to build a dataset or perform operations, we need to resample the data to the same resolution as the SWIR band.
#
# There are several ways to do this, including reproject from rioxarray, but since here we only want to divide resolution by exactly two, we'll use a simple mean through the coarsen function of Xarray.
#
# So to sum up, in the following cell you'll need to:
# - Open the green band of the same product as above,
# - Slice the data before reading it, we only want to load only the data of interest. Be carefull, we've got twice as many pixels at the beginning, so be sure to take the correct amount of pixels, and at the correct indices.
# - Apply coarsen to the result, with x=2, y=2, boundary='pad', and take the mean.
# - As above, filter nodata values.

# %%
green = rioxarray.open_rasterio(
    "gs://supaero/31TCH/SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2/SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2_FRE_B3.tif"
)
green = green[:, 8000:10000, 8000:10000]
# Rééchantillonage à 20m, diviser résolution par 2
green = green.coarsen(x=2, y=2, boundary="pad").mean()
# No data
green = green.where(green != NODATA)
green.rio.write_nodata(NODATA, encoded=True, inplace=True)
green

# %% [markdown]
# Then plot the DataArray you just created.
#
# You should observe the same mountains, but this time, with the green band, you should see some snow!

# %%
green.plot()

# %% [markdown]
# ### Compute the NDSI using DataArrays
#
# Since the two DataArrays are of the same dimension, you can already perform operations with both of them.
#
# Use them two compute the [Normalised Difference Snow Index (NDSI)](https://custom-scripts.sentinel-hub.com/custom-scripts/sentinel-2/ndsi/).
#
# This should be as straigthforward as with Numpy.

# %%
ndsi = (green - swir) / (green + swir)
ndsi

# %% [markdown]
# Did you try to plot it?

# %%
ndsi.plot()

# %% [markdown]
# It has been established by research that a level of 0.4 in NDSI usually means there is snow.
#
# Just use this threshold to compute a boolean DataArray representing the snow cover over this particular area, and plot it. There should be plenty of snow on your image.

# %%
(ndsi > 0.4).plot()  # noqa: PLR2004

# %% [markdown]
# ### Xarray Datasets
#
# Now, we'll just use what we've done above to build a Simple Dataset made of several variables, because this will be handy in the next part of the exercise.
#
# Building a Dataset is as simple as using its constructor (xr.Dataset()) and giving it a dict with a string name associated to a DataArray.
#
# Build a dataset with a green and swir variable pointing to the DataArray we built above, then display it to see its structure. You can also play with the Database buttons or metadata to have more informations.

# %%
sub_ds = xr.Dataset({"green": green, "swir": swir})
sub_ds

# %% [markdown]
# A nice feature about Dataset is to be able to build and store new variables. We'll see also in the next part that we can add Temporal index as dimensions.
#
# For now, we'll just create two new variable in this Dataset:
# - a ndsi variable, that is linked to the NDSI computation over the two other variables,
# - a snow variable, boolean array as above.
#
# Adding variable is a simple as affecting a new Column in pandas, e.g. dataset["ndsi"] = ...

# %%
sub_ds["ndsi"] = (sub_ds.green - sub_ds.swir) / (sub_ds.green + sub_ds.swir)
sub_ds["snow"] = sub_ds.ndsi > 0.4  # noqa: PLR2004
sub_ds

# %% [markdown]
# Then plot the snow variable, just to check:

# %%
sub_ds.snow.plot()

# %%
vmin, vmax = int(sub_ds.ndsi.min().compute()), int(sub_ds.ndsi.max().compute())
vmin, vmax

# %%
m = leafmap.Map(
    center=[42.48728928565912, 1.733106117905945],
    zoom=11,
)

m

# %%
from jupyter_tiler.titiler import add_data_array

url = await add_data_array(
    data_array=sub_ds.ndsi,
    colormap_name="viridis",
    colormap_range=(vmin, vmax),
)
m.add_tile_layer(
    name="NDSI Layer",
    url=url,
    attribution="Sentinel-2B",
)

# %% [markdown]
# ### Compute snow percentage over the area
#
# The end goalg below is to plot the evolution of snow cover accross a time serie. But how to plot a snow cover percentage over one product?
#
# You'll need to count pixels having snow, and divide this number by the number of pixels wich are not nodata.

# %%
sub_ds.snow.sum() / sub_ds.snow.count()

# %% [markdown]
# On this particular patch, you should get over 77% of snow cover.

# %% [markdown]
# ## Compute a time series analysis
#
# Now that we know how to create a single timestamp dataset, we'll build a dataset with a time dimension.
# The idea is to stack single temporal datasets into a single one using a new time dimension.
#
# Up to now, we've only built datasets that easily fit in memory, by taking only part of one observation.
# In order to be able to work on full images and on ten products, we'll need to use Dask.
#
# ### Start a Dask cluster
#
# Configure it according to your computing power. Then we'll need to set environment variable on every worker.

# %%
client = Client(n_workers=2, threads_per_worker=2, memory_limit="1GiB")
client

# %%
client.run(set_env)

# %% [markdown]
# It's really interesting when using Dask to start a real Distributed cluster (even on one machine like we've done above).
#
# This gives access to a nice Dashboard, just click on the link displayed above (ending with 8787/status). If you are using binder, you should replace the URL with something like:
#
# ```
# https://hub.2i2c.mybinder.org/user/guillaumeeb-supaero-otsu-course-4kfqus3j/proxy/8787/status
# ```
#
# First part of the URL should be copied from you Jupyterlab URL on your browser.

# %% [markdown]
# ### Define some functions to build Datasets
#
# OK, in order to simplify the building of our time serie, we'll define some functions for the following:
# - Reading one band of a product. It should also handle an optional resampling. This time, we also want to use a Dask backend.
# - Creating a single time Dataset with green and swir band.
#
# So first, we'll define a read_one_band(product, band, coarsen=1) function:
# - product is the name of the product, i.e. the "SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2" part, which is repeated in a folder, and in the file name.
# - band is the band identifier, i.e. B3 or B11 in our case. We always access "FRE" bands in our case.
# - coarsen is the level of subsambling, it should be 1 by default (no subsampling) for the SWIR band, set it to 2 for GREEN to perform a resampling.
# - When opening the file with rioxarray, we'll use two new arguments: chunks, and lock=False. chunks indicate that we want chunked array as a backend, so Dask Arrays. You use (-1, 1024 * coarsen, 1024*coarsen) as a value before opening the file.
# - We also want to remove the band dimension that is useless, in order to do so, just apply .squeeze('band', drop=True) right after the opening.

# %%
def read_one_band(product: str, band: str, coarsen: int = 1) -> xr.DataArray:
    chunks = (-1, 1024 * coarsen, 1024 * coarsen)
    band = rioxarray.open_rasterio(
        f"gs://supaero/31TCH/{product}/{product}_FRE_{band}.tif",
        chunks=chunks,
        lock=False,
    ).squeeze("band", drop=True)
    band = band.where(band != NODATA)
    band.rio.write_nodata(NODATA, encoded=True, inplace=True)
    if coarsen > 1:
        band = band.coarsen(x=coarsen, y=coarsen, boundary="pad").mean()
    return band

# %% [markdown]
# Try this function on the green band of "SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2", so with a coarsen=2 value, and whatch the HTML repr. What do you notice?

# %%
read_one_band("SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2", "B3", 2)

# %% [markdown]
# Now, we'll define a create_dataset(product) function.
#
# Product argument is the same as above, and it will create a 2 dimension dataset with two DataArray variables: green and swir, at the same resolution.

# %%
def create_dataset(product: str) -> xr.Dataset:
    return xr.Dataset(
        {
            "green": read_one_band(product, "B3", 2),
            "swir": read_one_band(product, "B11"),
        }
    )

# %% [markdown]
# Try it on the above product

# %%
create_dataset("SENTINEL2B_20191224-104910-788_L2A_T31TCH_C_V2-2")

# %% [markdown]
# ### Build our time serie
#
# We are now ready to build a time series of our ten products.
#
# In order to do that, we'll need:
# - our product list (which is built in the below cell)
# - A list of containing all of our datasets
# - A Pandas Datetime index corresponding to our product list (code also given)
# - Apply xarray concat on our dataset list associated with our new Index as a dimension.

# %%
product_list = [path.split("/")[-1] for path in fs.ls("supaero/31TCH")]
product_list

# %%
# Create time index
dates = [product.split("_")[1] for product in product_list]
dt_index = pd.to_datetime(dates, format="%Y%m%d-%H%M%S-%f")
dt_index.name = "time"
dt_index

# %% [markdown]
# So now, create a list by creating a dataset from all of the products above.
#
# Then, use xr.concat to create a new overall dataset with a new time dimension and all of our single time step datasets in it.

# %%
datasets = [create_dataset(product) for product in product_list]

# %%
complete_ds = xr.concat(datasets, dt_index)
complete_ds

# %% [markdown]
# ### Add NDSI and snow mask
#
# Just as with a single time step Dataset, you can easily add two new variables to this complete Dataset as above.
#
# So create the new ndsi and snow variables, as above.

# %%
complete_ds["ndsi"] = (complete_ds.green - complete_ds.swir) / (
    complete_ds.green + complete_ds.swir
)
complete_ds["snow"] = complete_ds.ndsi > 0.4  # noqa: PLR2004

# %% [markdown]
# ### Compute snow percentage time series over the whole image
#
# Did you notice?
#
# All the operation above where pretty fast, no? That's because we didn't really computed anything. By using Dask backend and Xarray, we only worked using product metadata, all the real values are still waiting to be computed. This is the lazy power of Dask with Xarray.
#
# But now, if we want some result, we'll need to trigger a computation.
#
# What we are interested in is a time series representing the snow percentage evolution over the ten dates.
#
# We'll need to count snow pixel and sum them over spatial dimension, count also the not nodata values over each time step on the spatial dimension, and just divide the two time series to get the percentage.
#
# In order to trigger the computation, we'll need to use compute method.
#
# Then whatch the Daks Dashboard. This should take some time, depending on your resources (on Binder it does).

# %%
# %%time
snow_percentage = (
    complete_ds.snow.sum(dim=["x", "y"]) / complete_ds.ndsi.count(dim=["x", "y"])
).compute()

# %%
snow_percentage

# %% [markdown]
# ### And what is the result?
#
# Now, we just want to plot the results.
#
# As we've not sorted our dataset by dates at the beginning, you'll want to do it first, using xarray sortby method.
#
# Then just plot, or better, plot.step(where="mid") for a nicer view (in my opinion).
#
# Does this snow cover percentage time serie looks right?

# %%
snow_percentage.sortby("time").plot()

# %%
snow_percentage.sortby("time").plot.step(where="mid")

# %% [markdown]
# # Extends other statistics
#
# - Snow area
# - NDSI
# - Add elevation, and compute snowline
